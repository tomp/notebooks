# %% [markdown]
# John Cook - Exponential Sums Make Pretty Pictures
# October 7, 2017
#
# https://www.johndcook.com/blog/2017/10/07/exponential-sums-make-pretty-pictures/

# %%
from bokeh.plotting import figure, output_notebook, show
from numpy import array, pi, exp, log

output_notebook()

N = 12000
def f(n):
    return n/10 + n**2/7 + n**3/17 

z = array( [exp( 2*pi*1j*f(n) ) for n in range(3, N+3)] )
z = z.cumsum()

p = figure(title="Exponential Sum (n/10 + n**2/7 + n**3/17)", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(z.real, z.imag, line_width=1)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a0b7e9f6-951a-4d33-82ef-0ac57b36f79d">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4fb500eb-995a-4dd7-a00e-611bc7c6e3f8"></div>
# </div>
